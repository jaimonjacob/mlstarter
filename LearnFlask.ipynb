# %% [markdown]
# Settng up a virtual env

# %%
# Create virtual environment
python -m venv myenv

# Activate
# first
 [[environment name}}\Scripts\activate.bat
# second
 [[environment name}}\Scripts\activate

# setting app (if app.py is not present)
set FLASK_APP=flaskdemo

# setting dev environment
set FLASK_ENV=development

# Run flask
flask run

# Development server
flask --app app.py --debug run


# Solution for creation of db error This typically means that you attempted to use
#    functionality that needed the current application.
#    To solve this, set up an application context with app.app_context().
#    See the documentation for more information.
  #  use the below after create app

app.app_context().push()
